# %%
import pandas as pd
from pymongo import MongoClient

# 1️⃣ Conexión a MongoDB
client = MongoClient("mongodb://localhost:27017/")
db = client["Bank_2025"]
collection = db["prestamos"]

# 2️⃣ Leer el CSV
df = pd.read_csv("../database/bancos_clean.csv")

# 3️⃣ Convertir a diccionario e insertar en MongoDB
data = df.to_dict(orient="records")
collection.insert_many(data)
print("✅ Datos insertados en MongoDB correctamente.")

# ==========================================
# CONSULTAS
# ==========================================

# ✅ A. Mostrar todos los documentos
print("\n📋 Visualizar todos los datos insertados en MongoDB:")
for doc in collection.find():
    print(doc)

# ✅ B. Mostrar solo algunos campos (num_cta y saldo)
print("\n📋 Mostrar solo número de cuenta y saldo:")
for doc in collection.find({}, {"_id": 0, "Num_Cta": 1, "Saldo": 1}):
    print(doc)

# ✅ C. Consultar con filtro (saldo > 10,000)
print("\n💰 Cuentas con saldo mayor a 10,000:")
consulta = {"Saldo": {"$gt": 10000}}
for doc in collection.find(consulta, {"_id": 0, "Cli_codigo": 1, "Saldo": 1}):
    print(doc)

# ✅ D. Contar cuántos documentos hay en total
total = collection.count_documents({})
print(f"\n📊 Total de registros en la colección: {total}")

# ✅ E. Buscar por sucursal específica
print("\n🏦 Cuentas de la sucursal Cajamarca:")
consulta = {"Sucursal": "Cajamarca"}
for doc in collection.find(consulta, {"_id": 0, "Sucursal": 1, "Num_Cta": 1, "Saldo": 1}):
    print(doc)

# ✅ F. Consultar solo clientes con un tipo de cuenta específico
print("\n💳 Cuentas de tipo 'CTA AHORROS SOLES':")
consulta = {"TipoCuenta": "CTA AHORROS SOLES"}
for doc in collection.find(consulta, {"_id": 0, "Cli_codigo": 1, "TipoCuenta": 1, "Saldo": 1}):
    print(doc)
# Out:
# ✅ Datos insertados en MongoDB correctamente.
#
# 📋 Visualizar todos los datos insertados en MongoDB:
# {'_id': ObjectId('68f1a428ef985cddd57c4592'), 'Num_Cta': '191-10001-71', 'Cli_codigo': 'C0001', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Callao', 'FechaApertura': '30/04/2010', 'Saldo': 8788.87}
# {'_id': ObjectId('68f1a428ef985cddd57c4593'), 'Num_Cta': '191-10002-10', 'Cli_codigo': 'C0002', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'San Isidro', 'FechaApertura': '03/07/2017', 'Saldo': 840.7}
# {'_id': ObjectId('68f1a428ef985cddd57c4594'), 'Num_Cta': '191-10003-25', 'Cli_codigo': 'C0003', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Miraflores', 'FechaApertura': '11/06/2012', 'Saldo': 10527.2}
# {'_id': ObjectId('68f1a428ef985cddd57c4595'), 'Num_Cta': '191-10004-94', 'Cli_codigo': 'C0004', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Callao', 'FechaApertura': '12/05/2013', 'Saldo': 8873.68}
# {'_id': ObjectId('68f1a428ef985cddd57c4596'), 'Num_Cta': '191-10005-78', 'Cli_codigo': 'C0005', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'San Isidro', 'FechaApertura': '03/09/2022', 'Saldo': 13944.09}
# {'_id': ObjectId('68f1a428ef985cddd57c4597'), 'Num_Cta': '191-10006-15', 'Cli_codigo': 'C0006', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Cajamarca', 'FechaApertura': '23/05/2018', 'Saldo': 14217.69}
# {'_id': ObjectId('68f1a428ef985cddd57c4598'), 'Num_Cta': '191-10007-47', 'Cli_codigo': 'C0007', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Lince', 'FechaApertura': '03/01/2024', 'Saldo': 14484.44}
# {'_id': ObjectId('68f1a428ef985cddd57c4599'), 'Num_Cta': '191-10008-27', 'Cli_codigo': 'C0008', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'La Molina', 'FechaApertura': '03/05/2017', 'Saldo': 11835.9}
# {'_id': ObjectId('68f1a428ef985cddd57c459a'), 'Num_Cta': '191-10009-59', 'Cli_codigo': 'C0009', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Miraflores', 'FechaApertura': '06/08/2015', 'Saldo': 9443.62}
# {'_id': ObjectId('68f1a428ef985cddd57c459b'), 'Num_Cta': '191-10010-66', 'Cli_codigo': 'C0010', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Lince', 'FechaApertura': '28/10/2017', 'Saldo': 14086.79}
# {'_id': ObjectId('68f1a428ef985cddd57c459c'), 'Num_Cta': '191-10011-75', 'Cli_codigo': 'C0011', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Lince', 'FechaApertura': '13/05/2020', 'Saldo': 13567.1}
# {'_id': ObjectId('68f1a428ef985cddd57c459d'), 'Num_Cta': '191-10012-80', 'Cli_codigo': 'C0012', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Miraflores', 'FechaApertura': '26/12/2013', 'Saldo': 1079.17}
# {'_id': ObjectId('68f1a428ef985cddd57c459e'), 'Num_Cta': '191-10013-22', 'Cli_codigo': 'C0013', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Cajamarca', 'FechaApertura': '23/06/2021', 'Saldo': 5314.1}
# {'_id': ObjectId('68f1a428ef985cddd57c459f'), 'Num_Cta': '191-10014-41', 'Cli_codigo': 'C0014', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Lince', 'FechaApertura': '09/01/2015', 'Saldo': 5287.87}
# {'_id': ObjectId('68f1a428ef985cddd57c45a0'), 'Num_Cta': '191-10015-61', 'Cli_codigo': 'C0015', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Surco', 'FechaApertura': '19/07/2010', 'Saldo': 3315.02}
# {'_id': ObjectId('68f1a428ef985cddd57c45a1'), 'Num_Cta': '191-10016-44', 'Cli_codigo': 'C0016', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Callao', 'FechaApertura': '08/09/2013', 'Saldo': 12646.98}
# {'_id': ObjectId('68f1a428ef985cddd57c45a2'), 'Num_Cta': '191-10017-46', 'Cli_codigo': 'C0017', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Surco', 'FechaApertura': '19/09/2018', 'Saldo': 8452.74}
# {'_id': ObjectId('68f1a428ef985cddd57c45a3'), 'Num_Cta': '191-10018-42', 'Cli_codigo': 'C0018', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Cajamarca', 'FechaApertura': '21/04/2020', 'Saldo': 8222.92}
# {'_id': ObjectId('68f1a428ef985cddd57c45a4'), 'Num_Cta': '191-10019-25', 'Cli_codigo': 'C0019', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Lince', 'FechaApertura': '14/03/2020', 'Saldo': 6265.03}
# {'_id': ObjectId('68f1a428ef985cddd57c45a5'), 'Num_Cta': '191-10020-77', 'Cli_codigo': 'C0020', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Cajamarca', 'FechaApertura': '19/09/2017', 'Saldo': 12326.7}
# {'_id': ObjectId('68f1a428ef985cddd57c45a6'), 'Num_Cta': '191-10021-88', 'Cli_codigo': 'C0021', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Miraflores', 'FechaApertura': '17/10/2024', 'Saldo': 4614.67}
# {'_id': ObjectId('68f1a428ef985cddd57c45a7'), 'Num_Cta': '191-10022-84', 'Cli_codigo': 'C0022', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Cajamarca', 'FechaApertura': '07/12/2012', 'Saldo': 5415.06}
# {'_id': ObjectId('68f1a428ef985cddd57c45a8'), 'Num_Cta': '191-10023-50', 'Cli_codigo': 'C0023', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'La Molina', 'FechaApertura': '01/03/2012', 'Saldo': 4182.85}
# {'_id': ObjectId('68f1a428ef985cddd57c45a9'), 'Num_Cta': '191-10024-72', 'Cli_codigo': 'C0024', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Callao', 'FechaApertura': '12/04/2010', 'Saldo': 7386.85}
# {'_id': ObjectId('68f1a428ef985cddd57c45aa'), 'Num_Cta': '191-10025-32', 'Cli_codigo': 'C0025', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Lince', 'FechaApertura': '14/10/2016', 'Saldo': 3758.67}
# {'_id': ObjectId('68f1a428ef985cddd57c45ab'), 'Num_Cta': '191-10026-88', 'Cli_codigo': 'C0026', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Surco', 'FechaApertura': '09/05/2019', 'Saldo': 4600.35}
# {'_id': ObjectId('68f1a428ef985cddd57c45ac'), 'Num_Cta': '191-10027-24', 'Cli_codigo': 'C0027', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'La Molina', 'FechaApertura': '10/05/2024', 'Saldo': 13058.73}
# {'_id': ObjectId('68f1a428ef985cddd57c45ad'), 'Num_Cta': '191-10028-94', 'Cli_codigo': 'C0028', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Surco', 'FechaApertura': '01/09/2011', 'Saldo': 6840.9}
# {'_id': ObjectId('68f1a428ef985cddd57c45ae'), 'Num_Cta': '191-10029-17', 'Cli_codigo': 'C0029', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Miraflores', 'FechaApertura': '01/03/2010', 'Saldo': 14503.56}
# {'_id': ObjectId('68f1a428ef985cddd57c45af'), 'Num_Cta': '191-10030-77', 'Cli_codigo': 'C0030', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Cajamarca', 'FechaApertura': '23/01/2010', 'Saldo': 7329.16}
# {'_id': ObjectId('68f1a428ef985cddd57c45b0'), 'Num_Cta': '191-10031-25', 'Cli_codigo': 'C0031', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Miraflores', 'FechaApertura': '17/01/2023', 'Saldo': 11439.3}
# {'_id': ObjectId('68f1a428ef985cddd57c45b1'), 'Num_Cta': '191-10032-89', 'Cli_codigo': 'C0032', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Lince', 'FechaApertura': '26/08/2015', 'Saldo': 10851.33}
# {'_id': ObjectId('68f1a428ef985cddd57c45b2'), 'Num_Cta': '191-10033-42', 'Cli_codigo': 'C0033', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Miraflores', 'FechaApertura': '12/04/2013', 'Saldo': 5975.18}
# {'_id': ObjectId('68f1a428ef985cddd57c45b3'), 'Num_Cta': '191-10034-32', 'Cli_codigo': 'C0034', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'La Molina', 'FechaApertura': '26/10/2021', 'Saldo': 4321.54}
# {'_id': ObjectId('68f1a428ef985cddd57c45b4'), 'Num_Cta': '191-10035-48', 'Cli_codigo': 'C0035', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'San Isidro', 'FechaApertura': '01/09/2022', 'Saldo': 8373.74}
# {'_id': ObjectId('68f1a428ef985cddd57c45b5'), 'Num_Cta': '191-10036-57', 'Cli_codigo': 'C0036', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Lince', 'FechaApertura': '15/06/2015', 'Saldo': 14849.51}
# {'_id': ObjectId('68f1a428ef985cddd57c45b6'), 'Num_Cta': '191-10037-63', 'Cli_codigo': 'C0037', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Lince', 'FechaApertura': '05/12/2019', 'Saldo': 8908.37}
# {'_id': ObjectId('68f1a428ef985cddd57c45b7'), 'Num_Cta': '191-10038-22', 'Cli_codigo': 'C0038', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Lince', 'FechaApertura': '11/12/2021', 'Saldo': 13478.72}
# {'_id': ObjectId('68f1a428ef985cddd57c45b8'), 'Num_Cta': '191-10039-57', 'Cli_codigo': 'C0039', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Surco', 'FechaApertura': '03/11/2016', 'Saldo': 7813.77}
# {'_id': ObjectId('68f1a428ef985cddd57c45b9'), 'Num_Cta': '191-10040-13', 'Cli_codigo': 'C0040', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Lince', 'FechaApertura': '10/09/2013', 'Saldo': 4335.8}
# {'_id': ObjectId('68f1a428ef985cddd57c45ba'), 'Num_Cta': '191-10041-99', 'Cli_codigo': 'C0041', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Miraflores', 'FechaApertura': '01/05/2016', 'Saldo': 5753.76}
# {'_id': ObjectId('68f1a428ef985cddd57c45bb'), 'Num_Cta': '191-10042-70', 'Cli_codigo': 'C0042', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Cajamarca', 'FechaApertura': '19/03/2018', 'Saldo': 1976.58}
# {'_id': ObjectId('68f1a428ef985cddd57c45bc'), 'Num_Cta': '191-10043-80', 'Cli_codigo': 'C0043', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Lince', 'FechaApertura': '10/06/2021', 'Saldo': 3035.81}
# {'_id': ObjectId('68f1a428ef985cddd57c45bd'), 'Num_Cta': '191-10044-74', 'Cli_codigo': 'C0044', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Cajamarca', 'FechaApertura': '18/03/2015', 'Saldo': 8259.04}
# {'_id': ObjectId('68f1a428ef985cddd57c45be'), 'Num_Cta': '191-10045-17', 'Cli_codigo': 'C0045', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Cajamarca', 'FechaApertura': '18/03/2023', 'Saldo': 7582.14}
# {'_id': ObjectId('68f1a428ef985cddd57c45bf'), 'Num_Cta': '191-10046-23', 'Cli_codigo': 'C0046', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Callao', 'FechaApertura': '19/05/2017', 'Saldo': 2444.39}
# {'_id': ObjectId('68f1a428ef985cddd57c45c0'), 'Num_Cta': '191-10047-44', 'Cli_codigo': 'C0047', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Cajamarca', 'FechaApertura': '26/11/2017', 'Saldo': 8520.17}
# {'_id': ObjectId('68f1a428ef985cddd57c45c1'), 'Num_Cta': '191-10048-49', 'Cli_codigo': 'C0048', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Lince', 'FechaApertura': '25/08/2019', 'Saldo': 14440.59}
# {'_id': ObjectId('68f1a428ef985cddd57c45c2'), 'Num_Cta': '191-10049-72', 'Cli_codigo': 'C0049', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'San Isidro', 'FechaApertura': '29/09/2010', 'Saldo': 1869.83}
# {'_id': ObjectId('68f1a428ef985cddd57c45c3'), 'Num_Cta': '191-10050-10', 'Cli_codigo': 'C0050', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Callao', 'FechaApertura': '19/11/2020', 'Saldo': 13943.94}
# {'_id': ObjectId('68f1a428ef985cddd57c45c4'), 'Num_Cta': '191-10051-68', 'Cli_codigo': 'C0051', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Surco', 'FechaApertura': '21/11/2023', 'Saldo': 11633.28}
# {'_id': ObjectId('68f1a428ef985cddd57c45c5'), 'Num_Cta': '191-10052-76', 'Cli_codigo': 'C0052', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Callao', 'FechaApertura': '21/11/2018', 'Saldo': 9168.93}
# {'_id': ObjectId('68f1a428ef985cddd57c45c6'), 'Num_Cta': '191-10053-93', 'Cli_codigo': 'C0053', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'La Molina', 'FechaApertura': '05/01/2017', 'Saldo': 14130.55}
# {'_id': ObjectId('68f1a428ef985cddd57c45c7'), 'Num_Cta': '191-10054-99', 'Cli_codigo': 'C0054', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'La Molina', 'FechaApertura': '27/06/2016', 'Saldo': 8716.26}
# {'_id': ObjectId('68f1a428ef985cddd57c45c8'), 'Num_Cta': '191-10055-82', 'Cli_codigo': 'C0055', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Callao', 'FechaApertura': '02/02/2011', 'Saldo': 2522.85}
# {'_id': ObjectId('68f1a428ef985cddd57c45c9'), 'Num_Cta': '191-10056-91', 'Cli_codigo': 'C0056', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Cajamarca', 'FechaApertura': '10/10/2021', 'Saldo': 9145.81}
# {'_id': ObjectId('68f1a428ef985cddd57c45ca'), 'Num_Cta': '191-10057-72', 'Cli_codigo': 'C0057', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'San Isidro', 'FechaApertura': '18/09/2015', 'Saldo': 1970.69}
# {'_id': ObjectId('68f1a428ef985cddd57c45cb'), 'Num_Cta': '191-10058-47', 'Cli_codigo': 'C0058', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Cajamarca', 'FechaApertura': '24/12/2020', 'Saldo': 13519.72}
# {'_id': ObjectId('68f1a428ef985cddd57c45cc'), 'Num_Cta': '191-10059-83', 'Cli_codigo': 'C0059', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Callao', 'FechaApertura': '07/05/2019', 'Saldo': 2649.38}
# {'_id': ObjectId('68f1a428ef985cddd57c45cd'), 'Num_Cta': '191-10060-48', 'Cli_codigo': 'C0060', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'La Molina', 'FechaApertura': '13/08/2020', 'Saldo': 8821.91}
# {'_id': ObjectId('68f1a428ef985cddd57c45ce'), 'Num_Cta': '191-10061-84', 'Cli_codigo': 'C0061', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Cajamarca', 'FechaApertura': '07/05/2017', 'Saldo': 4434.98}
# {'_id': ObjectId('68f1a428ef985cddd57c45cf'), 'Num_Cta': '191-10062-57', 'Cli_codigo': 'C0062', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Lince', 'FechaApertura': '10/11/2017', 'Saldo': 583.36}
# {'_id': ObjectId('68f1a428ef985cddd57c45d0'), 'Num_Cta': '191-10063-69', 'Cli_codigo': 'C0063', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Surco', 'FechaApertura': '19/12/2013', 'Saldo': 9089.57}
# {'_id': ObjectId('68f1a428ef985cddd57c45d1'), 'Num_Cta': '191-10064-14', 'Cli_codigo': 'C0064', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Cajamarca', 'FechaApertura': '28/08/2018', 'Saldo': 5550.91}
# {'_id': ObjectId('68f1a428ef985cddd57c45d2'), 'Num_Cta': '191-10065-85', 'Cli_codigo': 'C0065', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'La Molina', 'FechaApertura': '26/02/2019', 'Saldo': 6295.65}
# {'_id': ObjectId('68f1a428ef985cddd57c45d3'), 'Num_Cta': '191-10066-45', 'Cli_codigo': 'C0066', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Callao', 'FechaApertura': '13/08/2019', 'Saldo': 8629.85}
# {'_id': ObjectId('68f1a428ef985cddd57c45d4'), 'Num_Cta': '191-10067-26', 'Cli_codigo': 'C0067', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Callao', 'FechaApertura': '29/01/2018', 'Saldo': 2868.94}
# {'_id': ObjectId('68f1a428ef985cddd57c45d5'), 'Num_Cta': '191-10068-11', 'Cli_codigo': 'C0068', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'La Molina', 'FechaApertura': '26/04/2019', 'Saldo': 8469.76}
# {'_id': ObjectId('68f1a428ef985cddd57c45d6'), 'Num_Cta': '191-10069-65', 'Cli_codigo': 'C0069', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'La Molina', 'FechaApertura': '22/10/2016', 'Saldo': 9950.21}
# {'_id': ObjectId('68f1a428ef985cddd57c45d7'), 'Num_Cta': '191-10070-99', 'Cli_codigo': 'C0070', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'La Molina', 'FechaApertura': '15/11/2011', 'Saldo': 5294.42}
# {'_id': ObjectId('68f1a428ef985cddd57c45d8'), 'Num_Cta': '191-10071-94', 'Cli_codigo': 'C0071', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Lince', 'FechaApertura': '01/01/2020', 'Saldo': 13146.48}
# {'_id': ObjectId('68f1a428ef985cddd57c45d9'), 'Num_Cta': '191-10072-94', 'Cli_codigo': 'C0072', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'La Molina', 'FechaApertura': '12/05/2024', 'Saldo': 11281.21}
# {'_id': ObjectId('68f1a428ef985cddd57c45da'), 'Num_Cta': '191-10073-35', 'Cli_codigo': 'C0073', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Cajamarca', 'FechaApertura': '21/04/2018', 'Saldo': 703.02}
# {'_id': ObjectId('68f1a428ef985cddd57c45db'), 'Num_Cta': '191-10074-80', 'Cli_codigo': 'C0074', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'La Molina', 'FechaApertura': '11/06/2022', 'Saldo': 11124.67}
# {'_id': ObjectId('68f1a428ef985cddd57c45dc'), 'Num_Cta': '191-10075-63', 'Cli_codigo': 'C0075', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Lince', 'FechaApertura': '27/03/2011', 'Saldo': 10421.76}
# {'_id': ObjectId('68f1a428ef985cddd57c45dd'), 'Num_Cta': '191-10076-66', 'Cli_codigo': 'C0076', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'La Molina', 'FechaApertura': '20/08/2018', 'Saldo': 565.13}
# {'_id': ObjectId('68f1a428ef985cddd57c45de'), 'Num_Cta': '191-10077-17', 'Cli_codigo': 'C0077', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Miraflores', 'FechaApertura': '03/01/2010', 'Saldo': 12651.55}
# {'_id': ObjectId('68f1a428ef985cddd57c45df'), 'Num_Cta': '191-10078-99', 'Cli_codigo': 'C0078', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Surco', 'FechaApertura': '10/01/2019', 'Saldo': 1260.78}
# {'_id': ObjectId('68f1a428ef985cddd57c45e0'), 'Num_Cta': '191-10079-62', 'Cli_codigo': 'C0079', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'San Isidro', 'FechaApertura': '24/01/2019', 'Saldo': 9355.35}
# {'_id': ObjectId('68f1a428ef985cddd57c45e1'), 'Num_Cta': '191-10080-60', 'Cli_codigo': 'C0080', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Callao', 'FechaApertura': '06/07/2021', 'Saldo': 1969.36}
# {'_id': ObjectId('68f1a428ef985cddd57c45e2'), 'Num_Cta': '191-10081-90', 'Cli_codigo': 'C0081', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Surco', 'FechaApertura': '19/03/2018', 'Saldo': 6002.05}
# {'_id': ObjectId('68f1a428ef985cddd57c45e3'), 'Num_Cta': '191-10082-65', 'Cli_codigo': 'C0082', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Surco', 'FechaApertura': '18/10/2017', 'Saldo': 12416.62}
# {'_id': ObjectId('68f1a428ef985cddd57c45e4'), 'Num_Cta': '191-10083-60', 'Cli_codigo': 'C0083', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'La Molina', 'FechaApertura': '16/08/2018', 'Saldo': 2829.48}
# {'_id': ObjectId('68f1a428ef985cddd57c45e5'), 'Num_Cta': '191-10084-71', 'Cli_codigo': 'C0084', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'La Molina', 'FechaApertura': '09/01/2016', 'Saldo': 11622.29}
# {'_id': ObjectId('68f1a428ef985cddd57c45e6'), 'Num_Cta': '191-10085-44', 'Cli_codigo': 'C0085', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Callao', 'FechaApertura': '17/08/2018', 'Saldo': 14397.13}
# {'_id': ObjectId('68f1a428ef985cddd57c45e7'), 'Num_Cta': '191-10086-57', 'Cli_codigo': 'C0086', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Cajamarca', 'FechaApertura': '26/07/2011', 'Saldo': 1662.16}
# {'_id': ObjectId('68f1a428ef985cddd57c45e8'), 'Num_Cta': '191-10087-96', 'Cli_codigo': 'C0087', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Surco', 'FechaApertura': '19/03/2016', 'Saldo': 7009.96}
# {'_id': ObjectId('68f1a428ef985cddd57c45e9'), 'Num_Cta': '191-10088-35', 'Cli_codigo': 'C0088', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Miraflores', 'FechaApertura': '13/03/2013', 'Saldo': 12680.2}
# {'_id': ObjectId('68f1a428ef985cddd57c45ea'), 'Num_Cta': '191-10089-74', 'Cli_codigo': 'C0089', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Callao', 'FechaApertura': '11/04/2012', 'Saldo': 2793.67}
# {'_id': ObjectId('68f1a428ef985cddd57c45eb'), 'Num_Cta': '191-10090-93', 'Cli_codigo': 'C0090', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Lince', 'FechaApertura': '12/06/2020', 'Saldo': 4834.6}
# {'_id': ObjectId('68f1a428ef985cddd57c45ec'), 'Num_Cta': '191-10091-32', 'Cli_codigo': 'C0091', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Callao', 'FechaApertura': '02/07/2015', 'Saldo': 725.29}
# {'_id': ObjectId('68f1a428ef985cddd57c45ed'), 'Num_Cta': '191-10092-20', 'Cli_codigo': 'C0092', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Surco', 'FechaApertura': '01/11/2017', 'Saldo': 9860.61}
# {'_id': ObjectId('68f1a428ef985cddd57c45ee'), 'Num_Cta': '191-10093-37', 'Cli_codigo': 'C0093', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Surco', 'FechaApertura': '02/08/2020', 'Saldo': 11994.65}
# {'_id': ObjectId('68f1a428ef985cddd57c45ef'), 'Num_Cta': '191-10094-93', 'Cli_codigo': 'C0094', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'La Molina', 'FechaApertura': '06/04/2011', 'Saldo': 7118.56}
# {'_id': ObjectId('68f1a428ef985cddd57c45f0'), 'Num_Cta': '191-10095-84', 'Cli_codigo': 'C0095', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Cajamarca', 'FechaApertura': '09/09/2015', 'Saldo': 5131.9}
# {'_id': ObjectId('68f1a428ef985cddd57c45f1'), 'Num_Cta': '191-10096-54', 'Cli_codigo': 'C0096', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Surco', 'FechaApertura': '13/12/2019', 'Saldo': 2354.97}
# {'_id': ObjectId('68f1a428ef985cddd57c45f2'), 'Num_Cta': '191-10097-75', 'Cli_codigo': 'C0097', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Surco', 'FechaApertura': '15/06/2020', 'Saldo': 4559.25}
# {'_id': ObjectId('68f1a428ef985cddd57c45f3'), 'Num_Cta': '191-10098-15', 'Cli_codigo': 'C0098', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Surco', 'FechaApertura': '14/07/2012', 'Saldo': 13264.5}
# {'_id': ObjectId('68f1a428ef985cddd57c45f4'), 'Num_Cta': '191-10099-19', 'Cli_codigo': 'C0099', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Miraflores', 'FechaApertura': '25/06/2024', 'Saldo': 14443.83}
# {'_id': ObjectId('68f1a428ef985cddd57c45f5'), 'Num_Cta': '191-10100-81', 'Cli_codigo': 'C0100', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Callao', 'FechaApertura': '24/03/2021', 'Saldo': 6334.62}
# {'_id': ObjectId('68f1a428ef985cddd57c45f6'), 'Num_Cta': '191-10101-70', 'Cli_codigo': 'C0101', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'La Molina', 'FechaApertura': '30/06/2020', 'Saldo': 3536.82}
# {'_id': ObjectId('68f1a428ef985cddd57c45f7'), 'Num_Cta': '191-10102-17', 'Cli_codigo': 'C0102', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'San Isidro', 'FechaApertura': '06/01/2013', 'Saldo': 2351.1}
# {'_id': ObjectId('68f1a428ef985cddd57c45f8'), 'Num_Cta': '191-10103-70', 'Cli_codigo': 'C0103', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Miraflores', 'FechaApertura': '16/05/2012', 'Saldo': 7000.6}
# {'_id': ObjectId('68f1a428ef985cddd57c45f9'), 'Num_Cta': '191-10104-54', 'Cli_codigo': 'C0104', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'La Molina', 'FechaApertura': '29/02/2012', 'Saldo': 2257.12}
# {'_id': ObjectId('68f1a428ef985cddd57c45fa'), 'Num_Cta': '191-10105-34', 'Cli_codigo': 'C0105', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'La Molina', 'FechaApertura': '05/04/2023', 'Saldo': 14811.8}
# {'_id': ObjectId('68f1a428ef985cddd57c45fb'), 'Num_Cta': '191-10106-81', 'Cli_codigo': 'C0106', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'La Molina', 'FechaApertura': '19/03/2015', 'Saldo': 14659.61}
# {'_id': ObjectId('68f1a428ef985cddd57c45fc'), 'Num_Cta': '191-10107-84', 'Cli_codigo': 'C0107', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'San Isidro', 'FechaApertura': '20/12/2022', 'Saldo': 5457.11}
# {'_id': ObjectId('68f1a428ef985cddd57c45fd'), 'Num_Cta': '191-10108-77', 'Cli_codigo': 'C0108', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Lince', 'FechaApertura': '18/08/2019', 'Saldo': 4523.13}
# {'_id': ObjectId('68f1a428ef985cddd57c45fe'), 'Num_Cta': '191-10109-76', 'Cli_codigo': 'C0109', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Miraflores', 'FechaApertura': '25/10/2013', 'Saldo': 1529.4}
# {'_id': ObjectId('68f1a428ef985cddd57c45ff'), 'Num_Cta': '191-10110-77', 'Cli_codigo': 'C0110', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Cajamarca', 'FechaApertura': '27/11/2023', 'Saldo': 13144.93}
# {'_id': ObjectId('68f1a428ef985cddd57c4600'), 'Num_Cta': '191-10111-30', 'Cli_codigo': 'C0111', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Surco', 'FechaApertura': '21/06/2015', 'Saldo': 6399.21}
# {'_id': ObjectId('68f1a428ef985cddd57c4601'), 'Num_Cta': '191-10112-68', 'Cli_codigo': 'C0112', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Surco', 'FechaApertura': '12/12/2018', 'Saldo': 6083.97}
# {'_id': ObjectId('68f1a428ef985cddd57c4602'), 'Num_Cta': '191-10113-19', 'Cli_codigo': 'C0113', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Cajamarca', 'FechaApertura': '10/07/2012', 'Saldo': 565.43}
# {'_id': ObjectId('68f1a428ef985cddd57c4603'), 'Num_Cta': '191-10114-71', 'Cli_codigo': 'C0114', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'San Isidro', 'FechaApertura': '26/12/2024', 'Saldo': 13260.33}
# {'_id': ObjectId('68f1a428ef985cddd57c4604'), 'Num_Cta': '191-10115-24', 'Cli_codigo': 'C0115', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Surco', 'FechaApertura': '15/07/2015', 'Saldo': 11770.59}
# {'_id': ObjectId('68f1a428ef985cddd57c4605'), 'Num_Cta': '191-10116-41', 'Cli_codigo': 'C0116', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Callao', 'FechaApertura': '16/12/2010', 'Saldo': 9425.42}
# {'_id': ObjectId('68f1a428ef985cddd57c4606'), 'Num_Cta': '191-10117-23', 'Cli_codigo': 'C0117', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Cajamarca', 'FechaApertura': '12/08/2017', 'Saldo': 6212.68}
# {'_id': ObjectId('68f1a428ef985cddd57c4607'), 'Num_Cta': '191-10118-50', 'Cli_codigo': 'C0118', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Cajamarca', 'FechaApertura': '17/11/2022', 'Saldo': 2534.13}
# {'_id': ObjectId('68f1a428ef985cddd57c4608'), 'Num_Cta': '191-10119-31', 'Cli_codigo': 'C0119', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'San Isidro', 'FechaApertura': '06/04/2021', 'Saldo': 1991.74}
# {'_id': ObjectId('68f1a428ef985cddd57c4609'), 'Num_Cta': '191-10120-12', 'Cli_codigo': 'C0120', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Miraflores', 'FechaApertura': '05/06/2011', 'Saldo': 5397.36}
# {'_id': ObjectId('68f1a428ef985cddd57c460a'), 'Num_Cta': '191-10121-30', 'Cli_codigo': 'C0121', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Surco', 'FechaApertura': '30/04/2016', 'Saldo': 2039.78}
# {'_id': ObjectId('68f1a428ef985cddd57c460b'), 'Num_Cta': '191-10122-69', 'Cli_codigo': 'C0122', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Miraflores', 'FechaApertura': '06/04/2023', 'Saldo': 6027.88}
# {'_id': ObjectId('68f1a428ef985cddd57c460c'), 'Num_Cta': '191-10123-80', 'Cli_codigo': 'C0123', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Surco', 'FechaApertura': '25/08/2017', 'Saldo': 2983.68}
# {'_id': ObjectId('68f1a428ef985cddd57c460d'), 'Num_Cta': '191-10124-67', 'Cli_codigo': 'C0124', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'San Isidro', 'FechaApertura': '16/06/2011', 'Saldo': 12701.52}
# {'_id': ObjectId('68f1a428ef985cddd57c460e'), 'Num_Cta': '191-10125-57', 'Cli_codigo': 'C0125', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'La Molina', 'FechaApertura': '13/01/2018', 'Saldo': 1027.83}
# {'_id': ObjectId('68f1a428ef985cddd57c460f'), 'Num_Cta': '191-10126-45', 'Cli_codigo': 'C0126', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'La Molina', 'FechaApertura': '15/04/2017', 'Saldo': 13521.17}
# {'_id': ObjectId('68f1a428ef985cddd57c4610'), 'Num_Cta': '191-10127-79', 'Cli_codigo': 'C0127', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Miraflores', 'FechaApertura': '31/03/2011', 'Saldo': 8526.12}
# {'_id': ObjectId('68f1a428ef985cddd57c4611'), 'Num_Cta': '191-10128-55', 'Cli_codigo': 'C0128', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'La Molina', 'FechaApertura': '08/02/2013', 'Saldo': 6632.57}
# {'_id': ObjectId('68f1a428ef985cddd57c4612'), 'Num_Cta': '191-10129-99', 'Cli_codigo': 'C0129', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'La Molina', 'FechaApertura': '17/04/2014', 'Saldo': 8860.21}
# {'_id': ObjectId('68f1a428ef985cddd57c4613'), 'Num_Cta': '191-10130-94', 'Cli_codigo': 'C0130', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Surco', 'FechaApertura': '03/01/2020', 'Saldo': 5206.35}
# {'_id': ObjectId('68f1a428ef985cddd57c4614'), 'Num_Cta': '191-10131-48', 'Cli_codigo': 'C0131', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Lince', 'FechaApertura': '12/06/2011', 'Saldo': 2811.74}
# {'_id': ObjectId('68f1a428ef985cddd57c4615'), 'Num_Cta': '191-10132-11', 'Cli_codigo': 'C0132', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Miraflores', 'FechaApertura': '27/11/2018', 'Saldo': 4803.84}
# {'_id': ObjectId('68f1a428ef985cddd57c4616'), 'Num_Cta': '191-10133-10', 'Cli_codigo': 'C0133', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'La Molina', 'FechaApertura': '21/06/2010', 'Saldo': 13087.12}
# {'_id': ObjectId('68f1a428ef985cddd57c4617'), 'Num_Cta': '191-10134-69', 'Cli_codigo': 'C0134', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'La Molina', 'FechaApertura': '30/06/2021', 'Saldo': 13407.13}
# {'_id': ObjectId('68f1a428ef985cddd57c4618'), 'Num_Cta': '191-10135-76', 'Cli_codigo': 'C0135', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Surco', 'FechaApertura': '15/06/2011', 'Saldo': 1879.0}
# {'_id': ObjectId('68f1a428ef985cddd57c4619'), 'Num_Cta': '191-10136-10', 'Cli_codigo': 'C0136', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'La Molina', 'FechaApertura': '14/02/2010', 'Saldo': 12202.36}
# {'_id': ObjectId('68f1a428ef985cddd57c461a'), 'Num_Cta': '191-10137-79', 'Cli_codigo': 'C0137', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Callao', 'FechaApertura': '04/03/2019', 'Saldo': 4831.06}
# {'_id': ObjectId('68f1a428ef985cddd57c461b'), 'Num_Cta': '191-10138-49', 'Cli_codigo': 'C0138', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Surco', 'FechaApertura': '14/09/2024', 'Saldo': 6382.07}
# {'_id': ObjectId('68f1a428ef985cddd57c461c'), 'Num_Cta': '191-10139-58', 'Cli_codigo': 'C0139', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Surco', 'FechaApertura': '04/08/2014', 'Saldo': 5154.31}
# {'_id': ObjectId('68f1a428ef985cddd57c461d'), 'Num_Cta': '191-10140-17', 'Cli_codigo': 'C0140', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Surco', 'FechaApertura': '20/09/2023', 'Saldo': 5513.61}
# {'_id': ObjectId('68f1a428ef985cddd57c461e'), 'Num_Cta': '191-10141-89', 'Cli_codigo': 'C0141', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Miraflores', 'FechaApertura': '09/03/2016', 'Saldo': 14443.21}
# {'_id': ObjectId('68f1a428ef985cddd57c461f'), 'Num_Cta': '191-10142-80', 'Cli_codigo': 'C0142', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Surco', 'FechaApertura': '21/05/2023', 'Saldo': 5897.2}
# {'_id': ObjectId('68f1a428ef985cddd57c4620'), 'Num_Cta': '191-10143-23', 'Cli_codigo': 'C0143', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Surco', 'FechaApertura': '02/05/2011', 'Saldo': 11997.88}
# {'_id': ObjectId('68f1a428ef985cddd57c4621'), 'Num_Cta': '191-10144-57', 'Cli_codigo': 'C0144', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'La Molina', 'FechaApertura': '10/10/2023', 'Saldo': 5473.5}
# {'_id': ObjectId('68f1a428ef985cddd57c4622'), 'Num_Cta': '191-10145-62', 'Cli_codigo': 'C0145', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Miraflores', 'FechaApertura': '28/02/2020', 'Saldo': 8158.51}
# {'_id': ObjectId('68f1a428ef985cddd57c4623'), 'Num_Cta': '191-10146-77', 'Cli_codigo': 'C0146', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Surco', 'FechaApertura': '15/05/2016', 'Saldo': 7990.85}
# {'_id': ObjectId('68f1a428ef985cddd57c4624'), 'Num_Cta': '191-10147-11', 'Cli_codigo': 'C0147', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Miraflores', 'FechaApertura': '10/01/2023', 'Saldo': 9655.96}
# {'_id': ObjectId('68f1a428ef985cddd57c4625'), 'Num_Cta': '191-10148-77', 'Cli_codigo': 'C0148', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Miraflores', 'FechaApertura': '24/11/2017', 'Saldo': 4365.46}
# {'_id': ObjectId('68f1a428ef985cddd57c4626'), 'Num_Cta': '191-10149-50', 'Cli_codigo': 'C0149', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Surco', 'FechaApertura': '16/08/2023', 'Saldo': 7427.1}
# {'_id': ObjectId('68f1a428ef985cddd57c4627'), 'Num_Cta': '191-10150-95', 'Cli_codigo': 'C0150', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'La Molina', 'FechaApertura': '19/09/2016', 'Saldo': 5246.86}
# {'_id': ObjectId('68f1a428ef985cddd57c4628'), 'Num_Cta': '191-10151-85', 'Cli_codigo': 'C0151', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Callao', 'FechaApertura': '29/11/2011', 'Saldo': 1364.73}
# {'_id': ObjectId('68f1a428ef985cddd57c4629'), 'Num_Cta': '191-10152-83', 'Cli_codigo': 'C0152', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Lince', 'FechaApertura': '28/08/2014', 'Saldo': 11640.99}
# {'_id': ObjectId('68f1a428ef985cddd57c462a'), 'Num_Cta': '191-10153-98', 'Cli_codigo': 'C0153', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'La Molina', 'FechaApertura': '11/11/2021', 'Saldo': 14325.49}
# {'_id': ObjectId('68f1a428ef985cddd57c462b'), 'Num_Cta': '191-10154-70', 'Cli_codigo': 'C0154', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Lince', 'FechaApertura': '07/09/2010', 'Saldo': 13591.28}
# {'_id': ObjectId('68f1a428ef985cddd57c462c'), 'Num_Cta': '191-10155-82', 'Cli_codigo': 'C0155', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Lince', 'FechaApertura': '19/10/2024', 'Saldo': 1290.98}
# {'_id': ObjectId('68f1a428ef985cddd57c462d'), 'Num_Cta': '191-10156-62', 'Cli_codigo': 'C0156', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Surco', 'FechaApertura': '28/10/2012', 'Saldo': 8114.17}
# {'_id': ObjectId('68f1a428ef985cddd57c462e'), 'Num_Cta': '191-10157-71', 'Cli_codigo': 'C0157', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Cajamarca', 'FechaApertura': '14/04/2010', 'Saldo': 10290.32}
# {'_id': ObjectId('68f1a428ef985cddd57c462f'), 'Num_Cta': '191-10158-80', 'Cli_codigo': 'C0158', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Miraflores', 'FechaApertura': '15/12/2015', 'Saldo': 9827.13}
# {'_id': ObjectId('68f1a428ef985cddd57c4630'), 'Num_Cta': '191-10159-88', 'Cli_codigo': 'C0159', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Lince', 'FechaApertura': '07/05/2016', 'Saldo': 10964.62}
# {'_id': ObjectId('68f1a428ef985cddd57c4631'), 'Num_Cta': '191-10160-80', 'Cli_codigo': 'C0160', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Miraflores', 'FechaApertura': '08/11/2021', 'Saldo': 5286.53}
# {'_id': ObjectId('68f1a428ef985cddd57c4632'), 'Num_Cta': '191-10161-95', 'Cli_codigo': 'C0161', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Cajamarca', 'FechaApertura': '23/04/2016', 'Saldo': 5938.59}
# {'_id': ObjectId('68f1a428ef985cddd57c4633'), 'Num_Cta': '191-10162-51', 'Cli_codigo': 'C0162', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Miraflores', 'FechaApertura': '15/06/2024', 'Saldo': 14854.96}
# {'_id': ObjectId('68f1a428ef985cddd57c4634'), 'Num_Cta': '191-10163-11', 'Cli_codigo': 'C0163', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Cajamarca', 'FechaApertura': '18/03/2014', 'Saldo': 8996.85}
# {'_id': ObjectId('68f1a428ef985cddd57c4635'), 'Num_Cta': '191-10164-27', 'Cli_codigo': 'C0164', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'San Isidro', 'FechaApertura': '24/08/2022', 'Saldo': 13405.15}
# {'_id': ObjectId('68f1a428ef985cddd57c4636'), 'Num_Cta': '191-10165-74', 'Cli_codigo': 'C0165', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'San Isidro', 'FechaApertura': '27/04/2023', 'Saldo': 13767.96}
# {'_id': ObjectId('68f1a428ef985cddd57c4637'), 'Num_Cta': '191-10166-69', 'Cli_codigo': 'C0166', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'La Molina', 'FechaApertura': '28/12/2013', 'Saldo': 9276.69}
# {'_id': ObjectId('68f1a428ef985cddd57c4638'), 'Num_Cta': '191-10167-65', 'Cli_codigo': 'C0167', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Callao', 'FechaApertura': '14/02/2017', 'Saldo': 14024.39}
# {'_id': ObjectId('68f1a428ef985cddd57c4639'), 'Num_Cta': '191-10168-59', 'Cli_codigo': 'C0168', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Cajamarca', 'FechaApertura': '01/03/2016', 'Saldo': 3046.08}
# {'_id': ObjectId('68f1a428ef985cddd57c463a'), 'Num_Cta': '191-10169-56', 'Cli_codigo': 'C0169', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'San Isidro', 'FechaApertura': '14/04/2014', 'Saldo': 2525.91}
# {'_id': ObjectId('68f1a428ef985cddd57c463b'), 'Num_Cta': '191-10170-20', 'Cli_codigo': 'C0170', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'San Isidro', 'FechaApertura': '01/04/2017', 'Saldo': 9542.63}
# {'_id': ObjectId('68f1a428ef985cddd57c463c'), 'Num_Cta': '191-10171-64', 'Cli_codigo': 'C0171', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Surco', 'FechaApertura': '15/07/2022', 'Saldo': 14789.22}
# {'_id': ObjectId('68f1a428ef985cddd57c463d'), 'Num_Cta': '191-10172-49', 'Cli_codigo': 'C0172', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Cajamarca', 'FechaApertura': '20/06/2020', 'Saldo': 8493.78}
# {'_id': ObjectId('68f1a428ef985cddd57c463e'), 'Num_Cta': '191-10173-59', 'Cli_codigo': 'C0173', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'La Molina', 'FechaApertura': '21/06/2024', 'Saldo': 12587.07}
# {'_id': ObjectId('68f1a428ef985cddd57c463f'), 'Num_Cta': '191-10174-44', 'Cli_codigo': 'C0174', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'San Isidro', 'FechaApertura': '27/05/2010', 'Saldo': 12250.21}
# {'_id': ObjectId('68f1a428ef985cddd57c4640'), 'Num_Cta': '191-10175-85', 'Cli_codigo': 'C0175', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'San Isidro', 'FechaApertura': '30/06/2011', 'Saldo': 5042.56}
# {'_id': ObjectId('68f1a428ef985cddd57c4641'), 'Num_Cta': '191-10176-46', 'Cli_codigo': 'C0176', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Cajamarca', 'FechaApertura': '29/11/2024', 'Saldo': 4575.53}
# {'_id': ObjectId('68f1a428ef985cddd57c4642'), 'Num_Cta': '191-10177-90', 'Cli_codigo': 'C0177', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Lince', 'FechaApertura': '08/09/2020', 'Saldo': 3766.14}
# {'_id': ObjectId('68f1a428ef985cddd57c4643'), 'Num_Cta': '191-10178-87', 'Cli_codigo': 'C0178', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Callao', 'FechaApertura': '26/11/2010', 'Saldo': 7493.86}
# {'_id': ObjectId('68f1a428ef985cddd57c4644'), 'Num_Cta': '191-10179-98', 'Cli_codigo': 'C0179', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'La Molina', 'FechaApertura': '07/05/2014', 'Saldo': 2984.11}
# {'_id': ObjectId('68f1a428ef985cddd57c4645'), 'Num_Cta': '191-10180-36', 'Cli_codigo': 'C0180', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Surco', 'FechaApertura': '12/02/2015', 'Saldo': 6414.63}
# {'_id': ObjectId('68f1a428ef985cddd57c4646'), 'Num_Cta': '191-10181-80', 'Cli_codigo': 'C0181', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Cajamarca', 'FechaApertura': '03/02/2019', 'Saldo': 11831.39}
# {'_id': ObjectId('68f1a428ef985cddd57c4647'), 'Num_Cta': '191-10182-90', 'Cli_codigo': 'C0182', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Miraflores', 'FechaApertura': '09/04/2013', 'Saldo': 12483.97}
# {'_id': ObjectId('68f1a428ef985cddd57c4648'), 'Num_Cta': '191-10183-65', 'Cli_codigo': 'C0183', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Surco', 'FechaApertura': '10/07/2011', 'Saldo': 5342.43}
# {'_id': ObjectId('68f1a428ef985cddd57c4649'), 'Num_Cta': '191-10184-78', 'Cli_codigo': 'C0184', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Cajamarca', 'FechaApertura': '17/03/2012', 'Saldo': 8897.36}
# {'_id': ObjectId('68f1a428ef985cddd57c464a'), 'Num_Cta': '191-10185-91', 'Cli_codigo': 'C0185', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Lince', 'FechaApertura': '24/10/2013', 'Saldo': 12178.26}
# {'_id': ObjectId('68f1a428ef985cddd57c464b'), 'Num_Cta': '191-10186-52', 'Cli_codigo': 'C0186', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Lince', 'FechaApertura': '15/10/2017', 'Saldo': 7144.8}
# {'_id': ObjectId('68f1a428ef985cddd57c464c'), 'Num_Cta': '191-10187-18', 'Cli_codigo': 'C0187', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Lince', 'FechaApertura': '18/12/2020', 'Saldo': 14681.05}
# {'_id': ObjectId('68f1a428ef985cddd57c464d'), 'Num_Cta': '191-10188-67', 'Cli_codigo': 'C0188', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Lince', 'FechaApertura': '21/07/2018', 'Saldo': 9888.01}
# {'_id': ObjectId('68f1a428ef985cddd57c464e'), 'Num_Cta': '191-10189-62', 'Cli_codigo': 'C0189', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Miraflores', 'FechaApertura': '19/01/2024', 'Saldo': 2718.83}
# {'_id': ObjectId('68f1a428ef985cddd57c464f'), 'Num_Cta': '191-10190-74', 'Cli_codigo': 'C0190', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'La Molina', 'FechaApertura': '12/02/2019', 'Saldo': 12050.65}
# {'_id': ObjectId('68f1a428ef985cddd57c4650'), 'Num_Cta': '191-10191-29', 'Cli_codigo': 'C0191', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Lince', 'FechaApertura': '08/08/2019', 'Saldo': 4822.0}
# {'_id': ObjectId('68f1a428ef985cddd57c4651'), 'Num_Cta': '191-10192-38', 'Cli_codigo': 'C0192', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'La Molina', 'FechaApertura': '27/04/2023', 'Saldo': 6991.29}
# {'_id': ObjectId('68f1a428ef985cddd57c4652'), 'Num_Cta': '191-10193-71', 'Cli_codigo': 'C0193', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'San Isidro', 'FechaApertura': '26/09/2020', 'Saldo': 9932.05}
# {'_id': ObjectId('68f1a428ef985cddd57c4653'), 'Num_Cta': '191-10194-56', 'Cli_codigo': 'C0194', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Lince', 'FechaApertura': '14/09/2023', 'Saldo': 9920.65}
# {'_id': ObjectId('68f1a428ef985cddd57c4654'), 'Num_Cta': '191-10195-80', 'Cli_codigo': 'C0195', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Lince', 'FechaApertura': '09/10/2020', 'Saldo': 5085.26}
# {'_id': ObjectId('68f1a428ef985cddd57c4655'), 'Num_Cta': '191-10196-51', 'Cli_codigo': 'C0196', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Cajamarca', 'FechaApertura': '28/01/2021', 'Saldo': 2438.04}
# {'_id': ObjectId('68f1a428ef985cddd57c4656'), 'Num_Cta': '191-10197-33', 'Cli_codigo': 'C0197', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Miraflores', 'FechaApertura': '26/10/2020', 'Saldo': 6626.83}
# {'_id': ObjectId('68f1a428ef985cddd57c4657'), 'Num_Cta': '191-10198-39', 'Cli_codigo': 'C0198', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Callao', 'FechaApertura': '19/05/2012', 'Saldo': 8138.49}
# {'_id': ObjectId('68f1a428ef985cddd57c4658'), 'Num_Cta': '191-10199-23', 'Cli_codigo': 'C0199', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Callao', 'FechaApertura': '09/01/2017', 'Saldo': 4048.9}
# {'_id': ObjectId('68f1a428ef985cddd57c4659'), 'Num_Cta': '191-10200-10', 'Cli_codigo': 'C0200', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'San Isidro', 'FechaApertura': '18/05/2019', 'Saldo': 3891.81}
# {'_id': ObjectId('68f1a428ef985cddd57c465a'), 'Num_Cta': '191-10201-54', 'Cli_codigo': 'C0201', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'San Isidro', 'FechaApertura': '02/05/2022', 'Saldo': 14444.53}
# {'_id': ObjectId('68f1a428ef985cddd57c465b'), 'Num_Cta': '191-10202-82', 'Cli_codigo': 'C0202', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Cajamarca', 'FechaApertura': '30/04/2023', 'Saldo': 4560.71}
# {'_id': ObjectId('68f1a428ef985cddd57c465c'), 'Num_Cta': '191-10203-34', 'Cli_codigo': 'C0203', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Callao', 'FechaApertura': '02/08/2024', 'Saldo': 4951.83}
# {'_id': ObjectId('68f1a428ef985cddd57c465d'), 'Num_Cta': '191-10204-59', 'Cli_codigo': 'C0204', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Surco', 'FechaApertura': '21/08/2015', 'Saldo': 14139.5}
# {'_id': ObjectId('68f1a428ef985cddd57c465e'), 'Num_Cta': '191-10205-91', 'Cli_codigo': 'C0205', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Callao', 'FechaApertura': '22/01/2016', 'Saldo': 914.82}
# {'_id': ObjectId('68f1a428ef985cddd57c465f'), 'Num_Cta': '191-10206-37', 'Cli_codigo': 'C0206', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'San Isidro', 'FechaApertura': '12/07/2017', 'Saldo': 13079.88}
# {'_id': ObjectId('68f1a428ef985cddd57c4660'), 'Num_Cta': '191-10207-34', 'Cli_codigo': 'C0207', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Surco', 'FechaApertura': '23/07/2017', 'Saldo': 3118.42}
# {'_id': ObjectId('68f1a428ef985cddd57c4661'), 'Num_Cta': '191-10208-77', 'Cli_codigo': 'C0208', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Lince', 'FechaApertura': '28/06/2020', 'Saldo': 1412.62}
# {'_id': ObjectId('68f1a428ef985cddd57c4662'), 'Num_Cta': '191-10209-63', 'Cli_codigo': 'C0209', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Miraflores', 'FechaApertura': '09/03/2012', 'Saldo': 7354.91}
# {'_id': ObjectId('68f1a428ef985cddd57c4663'), 'Num_Cta': '191-10210-41', 'Cli_codigo': 'C0210', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Callao', 'FechaApertura': '23/07/2023', 'Saldo': 6602.95}
# {'_id': ObjectId('68f1a428ef985cddd57c4664'), 'Num_Cta': '191-10211-83', 'Cli_codigo': 'C0211', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Cajamarca', 'FechaApertura': '27/11/2017', 'Saldo': 1672.65}
# {'_id': ObjectId('68f1a428ef985cddd57c4665'), 'Num_Cta': '191-10212-67', 'Cli_codigo': 'C0212', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Callao', 'FechaApertura': '15/04/2019', 'Saldo': 4924.53}
# {'_id': ObjectId('68f1a428ef985cddd57c4666'), 'Num_Cta': '191-10213-70', 'Cli_codigo': 'C0213', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Surco', 'FechaApertura': '31/12/2022', 'Saldo': 1207.03}
# {'_id': ObjectId('68f1a428ef985cddd57c4667'), 'Num_Cta': '191-10214-58', 'Cli_codigo': 'C0214', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Cajamarca', 'FechaApertura': '16/11/2021', 'Saldo': 9491.94}
# {'_id': ObjectId('68f1a428ef985cddd57c4668'), 'Num_Cta': '191-10215-10', 'Cli_codigo': 'C0215', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'San Isidro', 'FechaApertura': '21/06/2017', 'Saldo': 3429.52}
# {'_id': ObjectId('68f1a428ef985cddd57c4669'), 'Num_Cta': '191-10216-68', 'Cli_codigo': 'C0216', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Miraflores', 'FechaApertura': '10/09/2023', 'Saldo': 4788.62}
# {'_id': ObjectId('68f1a428ef985cddd57c466a'), 'Num_Cta': '191-10217-26', 'Cli_codigo': 'C0217', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'San Isidro', 'FechaApertura': '16/04/2023', 'Saldo': 4194.04}
# {'_id': ObjectId('68f1a428ef985cddd57c466b'), 'Num_Cta': '191-10218-81', 'Cli_codigo': 'C0218', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'La Molina', 'FechaApertura': '15/09/2023', 'Saldo': 12761.79}
# {'_id': ObjectId('68f1a428ef985cddd57c466c'), 'Num_Cta': '191-10219-74', 'Cli_codigo': 'C0219', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Lince', 'FechaApertura': '06/12/2019', 'Saldo': 10805.69}
# {'_id': ObjectId('68f1a428ef985cddd57c466d'), 'Num_Cta': '191-10220-99', 'Cli_codigo': 'C0220', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Miraflores', 'FechaApertura': '17/10/2019', 'Saldo': 10059.61}
# {'_id': ObjectId('68f1a428ef985cddd57c466e'), 'Num_Cta': '191-10221-90', 'Cli_codigo': 'C0221', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Miraflores', 'FechaApertura': '18/05/2019', 'Saldo': 8788.76}
# {'_id': ObjectId('68f1a428ef985cddd57c466f'), 'Num_Cta': '191-10222-33', 'Cli_codigo': 'C0222', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Cajamarca', 'FechaApertura': '02/11/2016', 'Saldo': 5839.19}
# {'_id': ObjectId('68f1a428ef985cddd57c4670'), 'Num_Cta': '191-10223-81', 'Cli_codigo': 'C0223', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Cajamarca', 'FechaApertura': '19/12/2021', 'Saldo': 14713.39}
# {'_id': ObjectId('68f1a428ef985cddd57c4671'), 'Num_Cta': '191-10224-76', 'Cli_codigo': 'C0224', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'La Molina', 'FechaApertura': '21/12/2011', 'Saldo': 5331.39}
# {'_id': ObjectId('68f1a428ef985cddd57c4672'), 'Num_Cta': '191-10225-47', 'Cli_codigo': 'C0225', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'San Isidro', 'FechaApertura': '21/08/2018', 'Saldo': 11515.7}
# {'_id': ObjectId('68f1a428ef985cddd57c4673'), 'Num_Cta': '191-10226-79', 'Cli_codigo': 'C0226', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Lince', 'FechaApertura': '04/06/2022', 'Saldo': 10868.37}
# {'_id': ObjectId('68f1a428ef985cddd57c4674'), 'Num_Cta': '191-10227-57', 'Cli_codigo': 'C0227', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'La Molina', 'FechaApertura': '27/04/2019', 'Saldo': 3576.61}
# {'_id': ObjectId('68f1a428ef985cddd57c4675'), 'Num_Cta': '191-10228-73', 'Cli_codigo': 'C0228', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'Callao', 'FechaApertura': '17/09/2010', 'Saldo': 5692.85}
# {'_id': ObjectId('68f1a428ef985cddd57c4676'), 'Num_Cta': '191-10229-38', 'Cli_codigo': 'C0229', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Callao', 'FechaApertura': '25/06/2014', 'Saldo': 4622.57}
# {'_id': ObjectId('68f1a428ef985cddd57c4677'), 'Num_Cta': '191-10230-48', 'Cli_codigo': 'C0230', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Cajamarca', 'FechaApertura': '10/05/2012', 'Saldo': 5419.81}
# {'_id': ObjectId('68f1a428ef985cddd57c4678'), 'Num_Cta': '191-10231-71', 'Cli_codigo': 'C0231', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Surco', 'FechaApertura': '28/05/2022', 'Saldo': 14715.94}
# {'_id': ObjectId('68f1a428ef985cddd57c4679'), 'Num_Cta': '191-10232-53', 'Cli_codigo': 'C0232', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Lince', 'FechaApertura': '26/07/2015', 'Saldo': 9459.95}
# {'_id': ObjectId('68f1a428ef985cddd57c467a'), 'Num_Cta': '191-10233-26', 'Cli_codigo': 'C0233', 'TipoCuenta': 'CTA CORRIENTE', 'Sucursal': 'Miraflores', 'FechaApertura': '04/05/2010', 'Saldo': 3915.26}
# {'_id': ObjectId('68f1a428ef985cddd57c467b'), 'Num_Cta': '191-10234-99', 'Cli_codigo': 'C0234', 'TipoCuenta': 'CTA AHORROS DOLARES', 'Sucursal': 'La Molina', 'FechaApertura': '30/11/2014', 'Saldo': 5697.3}
# {'_id': ObjectId('68f1a428ef985cddd57c467c'), 'Num_Cta': '191-10235-18', 'Cli_codigo': 'C0235', 'TipoCuenta': 'CTA AHORROS SOLES', 'Sucursal': 'Miraflores', 'FechaApertura': '12/02/2012', 'Saldo': 8795.24}
# ...
# {'Cli_codigo': 'C0579', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 14626.45}
# {'Cli_codigo': 'C0580', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 13166.39}
# {'Cli_codigo': 'C0581', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 9220.09}
# {'Cli_codigo': 'C0582', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 7810.14}
# {'Cli_codigo': 'C0583', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 6216.62}
# {'Cli_codigo': 'C0586', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 7545.9}
# {'Cli_codigo': 'C0587', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 2541.26}
# {'Cli_codigo': 'C0588', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 2915.22}
# {'Cli_codigo': 'C0589', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 7013.27}
# {'Cli_codigo': 'C0593', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 7678.17}
# {'Cli_codigo': 'C0599', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 7332.52}
# {'Cli_codigo': 'C0602', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 4465.06}
# {'Cli_codigo': 'C0603', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 13110.44}
# {'Cli_codigo': 'C0604', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 9605.76}
# {'Cli_codigo': 'C0607', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 12410.53}
# {'Cli_codigo': 'C0608', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 8833.34}
# {'Cli_codigo': 'C0610', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 12817.45}
# {'Cli_codigo': 'C0611', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 6446.51}
# {'Cli_codigo': 'C0612', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 1697.48}
# {'Cli_codigo': 'C0616', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 2450.11}
# {'Cli_codigo': 'C0618', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 1627.05}
# {'Cli_codigo': 'C0620', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 2710.27}
# {'Cli_codigo': 'C0621', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 7111.33}
# {'Cli_codigo': 'C0627', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 10469.72}
# {'Cli_codigo': 'C0631', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 9242.38}
# {'Cli_codigo': 'C0633', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 5002.06}
# {'Cli_codigo': 'C0634', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 14261.53}
# {'Cli_codigo': 'C0636', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 8747.93}
# {'Cli_codigo': 'C0639', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 6408.78}
# {'Cli_codigo': 'C0641', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 7095.25}
# {'Cli_codigo': 'C0643', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 5655.13}
# {'Cli_codigo': 'C0645', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 10841.95}
# {'Cli_codigo': 'C0647', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 4295.07}
# {'Cli_codigo': 'C0648', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 3281.84}
# {'Cli_codigo': 'C0649', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 13525.77}
# {'Cli_codigo': 'C0650', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 8889.07}
# {'Cli_codigo': 'C0654', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 7592.88}
# {'Cli_codigo': 'C0656', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 9070.6}
# {'Cli_codigo': 'C0657', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 2657.69}
# {'Cli_codigo': 'C0658', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 6247.49}
# {'Cli_codigo': 'C0659', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 836.53}
# {'Cli_codigo': 'C0660', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 7760.16}
# {'Cli_codigo': 'C0662', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 9585.77}
# {'Cli_codigo': 'C0663', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 8495.13}
# {'Cli_codigo': 'C0664', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 4525.61}
# {'Cli_codigo': 'C0669', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 2328.93}
# {'Cli_codigo': 'C0671', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 11178.69}
# {'Cli_codigo': 'C0673', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 8846.21}
# {'Cli_codigo': 'C0674', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 1872.99}
# {'Cli_codigo': 'C0676', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 10785.76}
# {'Cli_codigo': 'C0681', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 2888.38}
# {'Cli_codigo': 'C0683', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 5504.37}
# {'Cli_codigo': 'C0684', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 11974.43}
# {'Cli_codigo': 'C0685', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 6933.16}
# {'Cli_codigo': 'C0686', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 11237.9}
# {'Cli_codigo': 'C0687', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 2698.32}
# {'Cli_codigo': 'C0690', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 13584.13}
# {'Cli_codigo': 'C0694', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 5789.27}
# {'Cli_codigo': 'C0695', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 7115.97}
# {'Cli_codigo': 'C0696', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 2944.65}
# {'Cli_codigo': 'C0697', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 11870.07}
# {'Cli_codigo': 'C0700', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 9508.18}
# {'Cli_codigo': 'C0701', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 8261.54}
# {'Cli_codigo': 'C0703', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 8276.62}
# {'Cli_codigo': 'C0711', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 9204.77}
# {'Cli_codigo': 'C0713', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 13460.46}
# {'Cli_codigo': 'C0715', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 10515.94}
# {'Cli_codigo': 'C0718', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 5648.44}
# {'Cli_codigo': 'C0721', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 10912.78}
# {'Cli_codigo': 'C0725', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 11726.9}
# {'Cli_codigo': 'C0726', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 3217.14}
# {'Cli_codigo': 'C0729', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 2390.48}
# {'Cli_codigo': 'C0734', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 10744.74}
# {'Cli_codigo': 'C0735', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 10815.03}
# {'Cli_codigo': 'C0736', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 2558.57}
# {'Cli_codigo': 'C0737', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 6460.18}
# {'Cli_codigo': 'C0738', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 13706.73}
# {'Cli_codigo': 'C0740', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 721.68}
# {'Cli_codigo': 'C0741', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 5954.87}
# {'Cli_codigo': 'C0743', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 3113.91}
# {'Cli_codigo': 'C0746', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 11940.46}
# {'Cli_codigo': 'C0747', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 1685.3}
# {'Cli_codigo': 'C0748', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 8081.95}
# {'Cli_codigo': 'C0750', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 7618.29}
# {'Cli_codigo': 'C0751', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 14097.18}
# {'Cli_codigo': 'C0752', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 10787.1}
# {'Cli_codigo': 'C0755', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 4508.73}
# {'Cli_codigo': 'C0757', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 14078.09}
# {'Cli_codigo': 'C0760', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 4746.57}
# {'Cli_codigo': 'C0761', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 3621.55}
# {'Cli_codigo': 'C0763', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 8734.29}
# {'Cli_codigo': 'C0764', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 12118.64}
# {'Cli_codigo': 'C0765', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 14257.16}
# {'Cli_codigo': 'C0768', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 8895.32}
# {'Cli_codigo': 'C0769', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 13505.25}
# {'Cli_codigo': 'C0771', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 2752.99}
# {'Cli_codigo': 'C0772', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 4036.6}
# {'Cli_codigo': 'C0773', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 3667.11}
# {'Cli_codigo': 'C0774', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 9975.65}
# {'Cli_codigo': 'C0775', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 3147.36}
# {'Cli_codigo': 'C0776', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 4222.74}
# {'Cli_codigo': 'C0778', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 1159.09}
# {'Cli_codigo': 'C0781', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 14265.92}
# {'Cli_codigo': 'C0783', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 2136.0}
# {'Cli_codigo': 'C0784', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 9252.8}
# {'Cli_codigo': 'C0785', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 2563.2}
# {'Cli_codigo': 'C0786', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 3181.67}
# {'Cli_codigo': 'C0787', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 8383.2}
# {'Cli_codigo': 'C0790', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 3040.02}
# {'Cli_codigo': 'C0791', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 1740.03}
# {'Cli_codigo': 'C0796', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 7417.19}
# {'Cli_codigo': 'C0802', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 5582.27}
# {'Cli_codigo': 'C0804', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 10868.41}
# {'Cli_codigo': 'C0805', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 5808.64}
# {'Cli_codigo': 'C0809', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 6551.06}
# {'Cli_codigo': 'C0810', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 10051.01}
# {'Cli_codigo': 'C0814', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 2731.99}
# {'Cli_codigo': 'C0815', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 4245.94}
# {'Cli_codigo': 'C0816', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 5441.84}
# {'Cli_codigo': 'C0818', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 9893.95}
# {'Cli_codigo': 'C0819', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 14318.98}
# {'Cli_codigo': 'C0822', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 6960.16}
# {'Cli_codigo': 'C0826', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 7639.1}
# {'Cli_codigo': 'C0827', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 7239.54}
# {'Cli_codigo': 'C0828', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 6031.67}
# {'Cli_codigo': 'C0831', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 3368.19}
# {'Cli_codigo': 'C0832', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 5714.69}
# {'Cli_codigo': 'C0833', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 9667.75}
# {'Cli_codigo': 'C0834', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 9057.84}
# {'Cli_codigo': 'C0836', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 5848.1}
# {'Cli_codigo': 'C0837', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 781.31}
# {'Cli_codigo': 'C0839', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 10928.47}
# {'Cli_codigo': 'C0840', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 10175.69}
# {'Cli_codigo': 'C0841', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 4785.03}
# {'Cli_codigo': 'C0842', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 3218.98}
# {'Cli_codigo': 'C0843', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 9415.94}
# {'Cli_codigo': 'C0848', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 2142.05}
# {'Cli_codigo': 'C0854', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 12146.02}
# {'Cli_codigo': 'C0859', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 10933.73}
# {'Cli_codigo': 'C0861', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 6845.15}
# {'Cli_codigo': 'C0862', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 3115.21}
# {'Cli_codigo': 'C0863', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 757.27}
# {'Cli_codigo': 'C0864', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 14963.75}
# {'Cli_codigo': 'C0865', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 9377.19}
# {'Cli_codigo': 'C0866', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 13774.5}
# {'Cli_codigo': 'C0868', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 14402.47}
# {'Cli_codigo': 'C0869', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 8591.7}
# {'Cli_codigo': 'C0870', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 8280.03}
# {'Cli_codigo': 'C0871', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 13636.64}
# {'Cli_codigo': 'C0873', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 8699.7}
# {'Cli_codigo': 'C0875', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 4805.34}
# {'Cli_codigo': 'C0877', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 845.49}
# {'Cli_codigo': 'C0878', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 8548.02}
# {'Cli_codigo': 'C0880', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 12320.51}
# {'Cli_codigo': 'C0881', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 13448.47}
# {'Cli_codigo': 'C0885', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 7983.24}
# {'Cli_codigo': 'C0886', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 8093.06}
# {'Cli_codigo': 'C0889', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 854.65}
# {'Cli_codigo': 'C0891', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 2068.25}
# {'Cli_codigo': 'C0892', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 3866.02}
# {'Cli_codigo': 'C0896', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 5526.53}
# {'Cli_codigo': 'C0898', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 5317.09}
# {'Cli_codigo': 'C0900', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 11955.2}
# {'Cli_codigo': 'C0902', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 14036.16}
# {'Cli_codigo': 'C0903', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 5374.06}
# {'Cli_codigo': 'C0904', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 3262.31}
# {'Cli_codigo': 'C0905', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 7881.61}
# {'Cli_codigo': 'C0907', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 2330.83}
# {'Cli_codigo': 'C0912', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 10746.38}
# {'Cli_codigo': 'C0913', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 6650.78}
# {'Cli_codigo': 'C0915', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 11496.44}
# {'Cli_codigo': 'C0918', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 12770.71}
# {'Cli_codigo': 'C0924', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 5864.04}
# {'Cli_codigo': 'C0925', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 6324.0}
# {'Cli_codigo': 'C0926', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 12341.19}
# {'Cli_codigo': 'C0927', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 8802.68}
# {'Cli_codigo': 'C0929', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 13376.75}
# {'Cli_codigo': 'C0931', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 3162.47}
# {'Cli_codigo': 'C0933', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 12564.35}
# {'Cli_codigo': 'C0937', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 597.52}
# {'Cli_codigo': 'C0938', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 9669.56}
# {'Cli_codigo': 'C0939', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 5362.72}
# {'Cli_codigo': 'C0944', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 9787.95}
# {'Cli_codigo': 'C0945', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 14780.67}
# {'Cli_codigo': 'C0946', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 12743.56}
# {'Cli_codigo': 'C0950', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 6310.0}
# {'Cli_codigo': 'C0951', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 11388.12}
# {'Cli_codigo': 'C0952', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 1708.85}
# {'Cli_codigo': 'C0956', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 12762.62}
# {'Cli_codigo': 'C0957', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 14335.61}
# {'Cli_codigo': 'C0959', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 6230.76}
# {'Cli_codigo': 'C0960', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 10686.26}
# {'Cli_codigo': 'C0961', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 14298.6}
# {'Cli_codigo': 'C0963', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 14514.42}
# {'Cli_codigo': 'C0969', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 1001.42}
# {'Cli_codigo': 'C0972', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 11767.75}
# {'Cli_codigo': 'C0973', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 11849.14}
# {'Cli_codigo': 'C0976', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 3006.2}
# {'Cli_codigo': 'C0977', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 10084.98}
# {'Cli_codigo': 'C0979', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 13902.43}
# {'Cli_codigo': 'C0983', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 13494.1}
# {'Cli_codigo': 'C0984', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 12010.67}
# {'Cli_codigo': 'C0989', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 8314.21}
# {'Cli_codigo': 'C0991', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 13491.29}
# {'Cli_codigo': 'C0995', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 9331.41}
# {'Cli_codigo': 'C0996', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 11583.4}
# {'Cli_codigo': 'C0999', 'TipoCuenta': 'CTA AHORROS SOLES', 'Saldo': 8063.29}
